# %% [markdown]
# ## PYNQ Quiz
# Thank you for watching our Xilinx Sponsor Workshop video on PYNQ! Below is a short quiz and [Additional Information](https://github.com/meganv9/pynq_quiz/blob/main/README.md) that will give a little more context on what you learned in the video about the PYNQ platform.

# %% [markdown]
# ## Short quiz on FPGA technology and the PYNQ platform!

# %%
from lib import quiz_widgets as qw

qw.show_questions()

# %% [markdown]
# #### Contacts
# Please contact one of us directly with any feedback or questions to find out how we can help:
#
# Megan Visaya: meganv@xilinx.com
#
# Philip Wu: philipwu@xilinx.com
#
# Romisaa Samhoud: romisaas@xilinx.com
